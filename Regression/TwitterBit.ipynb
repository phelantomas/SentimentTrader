# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

lm = LinearRegression()
df = pd.read_csv('C:/Users/Thomas/Desktop/features.csv')
#X = df.drop('change', axis=1)
X = df['sentiment']
Y = df['change']

X=X.values.reshape(len(X),1)
Y=Y.values.reshape(len(Y),1)

# %%
lm.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
sample = {'sentiment' : [.5]}
df = pd.DataFrame(sample)
lm.predict(df)
# Out:
# array([[ 1.86962836]])

# %%
print("Estimate intercept coeffecient", lm.intercept_)
# Out:
# Estimate intercept coeffecient [-0.47059982]

# %%
print("Number of coeffecients", len(lm.coef_))
# Out:
# Number of coeffecients 1

# %%
plt.scatter(X, Y)
plt.xlabel("Sentiment")
plt.ylabel("Change")
plt.show()

# %%
# Out:
# array([[ 4.20985653]])

# %%
plt.scatter(X, lm.predict(X))
plt.xlabel("Sentiment")
plt.ylabel("Predicted Sentiment")
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.33, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_train.shape)
# Out:
# (1820, 1)
# (897, 1)
# (1820,)
# (1820,)

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %%
plt.scatter(lm.predict(X_train), lm.predict(X_train)- Y_train, c='b', s=60, alpha=0.5)
plt.scatter(lm.predict(X_test), lm.predict(X_test)- Y_test, c='g', s=60)
plt.hlines(y=0, xmin=-1, xmax=1)
plt.title("Residual plot using training data (blue), and test (green)")
plt.ylabel("Residuals")
plt.show()

# %%
df.plot(kind='scatter', x='sentiment', y='change')
plt.plot(X_test, lm.predict(X_test), color='red',linewidth=3)
plt.show()
